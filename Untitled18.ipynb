# %% [markdown]
# <a href="https://colab.research.google.com/github/Godwin-Waswa/My-first-portfolio.github.io/blob/main/Untitled18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from matlaplib

# %% [markdown]
# # PYTHON PRACTICE

# %%
import numpy
import matplotlib
from matplotlib import pylab, mlab, pyplot
np = numpy
x = np.linspace(0,20,30)
y = x*x + 3*x - 4
z = x*x*x-1
print(x)
print(y)
print(np.array([x,y,z]).reshape(30,3))
pylab.xlabel('x \n (values)')
pylab.ylabel('y \n (values)')
pyplot.title('MY FIRST GRAPH')
pylab.plot(x,y,z,'r')
# Out:
# [ 0.          0.68965517  1.37931034  2.06896552  2.75862069  3.44827586
#   4.13793103  4.82758621  5.51724138  6.20689655  6.89655172  7.5862069
#   8.27586207  8.96551724  9.65517241 10.34482759 11.03448276 11.72413793
#  12.4137931  13.10344828 13.79310345 14.48275862 15.17241379 15.86206897
#  16.55172414 17.24137931 17.93103448 18.62068966 19.31034483 20.        ]
# [ -4.          -1.45541023   2.04042806   6.48751486  11.88585018
#   18.23543401  25.53626635  33.78834721  42.99167658  53.14625446
#   64.25208086  76.30915577  89.31747919 103.27705113 118.18787158
#  134.04994055 150.86325803 168.62782402 187.34363853 207.01070155
#  227.62901308 249.19857313 271.71938169 295.19143876 319.61474435
#  344.98929845 371.31510107 398.5921522  426.82045184 456.        ]
# [[ 0.00000000e+00  6.89655172e-01  1.37931034e+00]
#  [ 2.06896552e+00  2.75862069e+00  3.44827586e+00]
#  [ 4.13793103e+00  4.82758621e+00  5.51724138e+00]
#  [ 6.20689655e+00  6.89655172e+00  7.58620690e+00]
# ...

# %%
from matplotlib import pyplot as plt
languages = 'php','python','matlab','javascript'
popularity = [22,34,16,28]
colors = ['red','blue','green','black']
explode = (0.1,0.1,0.1,0.1)
plt.pie(popularity,labels=languages,explode = explode, shadow = True)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fd419858690>,
# ...
#  [Text(0.9246158941955844, 0.7649087842356762, 'php'),
#   Text(-0.9246158941955844, 0.7649087842356762, 'python'),
#   Text(-0.7649087842356762, -0.9246158941955842, 'matlab'),
#   Text(0.7649087842356759, -0.9246158941955845, 'javascript')])
